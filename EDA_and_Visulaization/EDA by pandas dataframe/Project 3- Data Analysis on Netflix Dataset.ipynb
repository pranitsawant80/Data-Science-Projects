# %% [markdown]
# # Project-3
# # Data Analysis on Netflix Dataset

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\PRANIT SAWANT\Downloads\PORTFOLIO\jupyter notebooks and datasets to build portfolio projects and practice\Datasets\8. Netflix Dataset.csv')

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.size
# Out:
# 85679

# %% [markdown]
# ### Task. 1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# ### Task. 2) Is there any Null Value present in any column ? Show with Heat-map.

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# ### 1) For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df[df.Title == 'House of Cards']
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
df['Release_Date']=pd.to_datetime(df['Release_Date'])

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# dtype: object

# %%
# df['year'] = df['Release_Date'].dt.year
df.insert(1,'year',df['Release_Date'].dt.year)
# df.drop(['year'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Show_Id', 'year', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: year, dtype: int64

# %%
df.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# year              10
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df.head()
# Out:
#   Show_Id    year Category  Title           Director  \
# 0      s1  2020.0  TV Show     3%                NaN
# 1      s2  2016.0    Movie  07:19  Jorge Michel Grau
# 2      s3  2018.0    Movie  23:59       Gilbert Chan
# 3      s4  2017.0    Movie      9        Shane Acker
# 4      s5  2020.0    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
# ...

# %%
df.Category.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# OR
sns.countplot(df['Category'])
# Out:
# C:\Users\PRANIT SAWANT\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# ### 4) Show all the Movies that were released in year 2000.

# %%
df.year.unique()
# Out:
# array([2020., 2016., 2018., 2017., 2019., 2021., 2015., 2013., 2011.,
#          nan, 2012., 2014., 2008., 2009., 2010.])

# %%
df.dtypes
# Out:
# Show_Id                 object
# year                   float64
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# dtype: object

# %%
# df[(df['Category']== 'Movie') & (df['year']== 2000)] OR
df[(df.Category== 'Movie') & (df.year== 2000)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, year, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# ### 5) Show only the Titles of all TV Shows that were released in India only.

# %%
df[(df.Category =='TV Show') & (df.Country== 'India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ### 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
df.Category.value_counts()
# Out:
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
df.Director.value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %% [markdown]
# ### 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
df[(df.Category== 'Movie') &((df.Type== 'Comedies') | (df.Country == 'United Kingdom'))]
# Out:
#      Show_Id    year Category                   Title                Director  \
# 19       s20  2018.0    Movie                     '89                     NaN
# 33       s34  2017.0    Movie            #realityhigh        Fernando Lebrija
# 72       s73  2021.0    Movie                17 Again             Burr Steers
# 82       s83  2018.0    Movie     2036 Origin Unknown           Hasraf Dulull
# 84       s85  2019.0    Movie               21 & Over  Jon Lucas, Scott Moore
# ...      ...     ...      ...                     ...                     ...
# 7634   s7633  2019.0    Movie            Wine Country             Amy Poehler
# 7649   s7648  2017.0    Movie           Without Gorky          Cosima Spender
# 7664   s7663  2020.0    Movie                 Work It           Laura Terruso
# 7688   s7687  2020.0    Movie  XV: Beyond the Tryline        Pierre Deschamps
# 7725   s7724  2017.0    Movie            You Can Tutu             James Brown
#
# ...

# %% [markdown]
# ### 8) What are the different Ratings defined by Netflix ?

# %%
df.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ### 9) How many Movies got the 'TV-14' rating, in Canada ?

# %%
df[(df.Category=='Movie') & (df.Rating=='TV-14') & (df.Country=='Canada')]
# Out:
#      Show_Id    year Category                                        Title  \
# 30       s31  2020.0    Movie                             #cats_the_mewvie
# 34       s35  2019.0    Movie                                        #Roxy
# 608     s609  2018.0    Movie                               At First Light
# 1506   s1507  2018.0    Movie                   Counterfeiting in Suburbia
# 3713   s3714  2017.0    Movie                            Long Time Running
# 3956   s3957  2019.0    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336  2017.0    Movie                   Sadie's Last Days on Earth
# 5393   s5393  2017.0    Movie                                   Sardaar ji
# 6062   s6062  2019.0    Movie                  The Accountant of Auschwitz
# 7025   s7024  2019.0    Movie                         The Wrong Babysitter
# 7041   s7040  2020.0    Movie               There's Something in the Water
#
#                                     Director  \
# ...

# %% [markdown]
# ### 10) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
df[(df.Category=='TV Show') & (df.Rating=='R') & (df.year> 2018)]
# Out:
#      Show_Id    year Category                                Title  \
# 6437   s6436  2019.0  TV Show  The Hateful Eight: Extended Version
#
#                Director                                               Cast  \
# 6437  Quentin Tarantino  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...
#
#      Country Release_Date Rating  Duration      Type  \
# 6437     NaN   2019-04-25      R  1 Season  TV Shows
#
#                                             Description
# 6437  Trapped at a stagecoach stop as a storm rages ...

# %% [markdown]
# ### 11) What is the maximum duration of a Movie/Show on Netflix ?

# %%
df.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
df.Duration.dtypes
# Out:
# dtype('O')

# %%
df[['Minutes','Unit']]= df['Duration'].str.split(' ',expand=True)

# %%
df.head(5)
# Out:
#   Show_Id    year Category  Title           Director  \
# 0      s1  2020.0  TV Show     3%                NaN
# 1      s2  2016.0    Movie  07:19  Jorge Michel Grau
# 2      s3  2018.0    Movie  23:59       Gilbert Chan
# 3      s4  2017.0    Movie      9        Shane Acker
# 4      s5  2020.0    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
# ...

# %%
df.Minutes.astype(int).max()
# Out:
# 312

# %%
df[df.Minutes=='312']
# Out:
#     Show_Id    year Category                       Title Director  \
# 957    s958  2018.0    Movie  Black Mirror: Bandersnatch      NaN
#
#                                                   Cast        Country  \
# 957  Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
#
#     Release_Date Rating Duration  \
# 957   2018-12-28  TV-MA  312 min
#
#                                                Type  \
# 957  Dramas, International Movies, Sci-Fi & Fantasy
#
#                                            Description Minutes Unit
# 957  In 1984, a young programmer begins to question...     312  min

# %% [markdown]
# ### 12) Which individual country has the Highest No. of TV Shows ?

# %%
df_tvshows= df[df['Category']=='TV Show' ]

# %%
df_tvshows
# Out:
#      Show_Id    year Category                  Title              Director  \
# 0         s1  2020.0  TV Show                     3%                   NaN
# 5         s6  2017.0  TV Show                     46           Serdar Akar
# 11       s12  2018.0  TV Show                   1983                   NaN
# 12       s13  2019.0  TV Show                   1994  Diego Enrique Osorno
# 16       s17  2019.0  TV Show                 Feb-09                   NaN
# ...      ...     ...      ...                    ...                   ...
# 7769   s7768  2016.0  TV Show     Zindagi Gulzar Hai                   NaN
# 7777   s7776  2020.0  TV Show             Zoids Wild                   NaN
# 7779   s7778  2019.0  TV Show            Zombie Dumb                   NaN
# 7781   s7780  2019.0  TV Show              Zona Rosa                   NaN
# 7787   s7786  2020.0  TV Show  Zumbo's Just Desserts                   NaN
#
#                                                    Cast  \
# ...

# %%
df_tvshows.Country.value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# ### 13) How can we sort the dataset by Year ?

# %%
df.sort_values('year')
# Out:
#      Show_Id    year Category                         Title  \
# 7115   s7114  2008.0    Movie          To and From New York
# 1765   s1766  2008.0  TV Show               Dinner for Five
# 3248   s3249  2009.0    Movie       Just Another Love Story
# 5766   s5766  2009.0    Movie                      Splatter
# 3840   s3841  2010.0    Movie   Mad Ron's Prevues from Hell
# ...      ...     ...      ...                           ...
# 3374   s3375     NaN  TV Show                      Kikoriki
# 3492   s3493     NaN  TV Show           La Familia P. Luche
# 3946   s3947     NaN  TV Show                         Maron
# 5138   s5138     NaN  TV Show                  Red vs. Blue
# 6066   s6066     NaN  TV Show  The Adventures of Figaro Pho
#
#                   Director                                               Cast  \
# 7115  Sorin Dan Mihalcescu  Barbara King, Shaana Diya, John Krisiukenas, Y...
# 1765                   NaN                                                NaN
# ...

# %% [markdown]
# ### 14) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
df[((df.Category=='Movie') & (df.Type=='Dramas')) | ((df.Category=='TV Show') & (df.Type=="Kids' TV"))] # see how here we use " " for the Word Kids' TV
# Out:
#      Show_Id    year Category                       Title        Director  \
# 4         s5  2020.0    Movie                          21  Robert Luketic
# 7         s8  2019.0    Movie                         187  Kevin Reynolds
# 111     s112  2020.0  TV Show                     44 Cats             NaN
# 170     s171  2019.0    Movie                A Family Man   Mark Williams
# 232     s233  2011.0    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...     ...      ...                         ...             ...
# 7668   s7667  2017.0  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  2018.0  TV Show                        Yoko             NaN
# 7719   s7718  2018.0  TV Show                         YOM             NaN
# 7758   s7757  2019.0  TV Show                          Z4             NaN
# 7761   s7760  2018.0  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# ...
